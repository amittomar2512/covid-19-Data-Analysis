# %%
#import Pandas Library
import pandas as pd

# %%
#import Numpy Library
import numpy as np

# %%
#To read the csv file.
covid_df=pd.read_csv('covid.csv')

# %%
# To show the top file datapoints of the dataset.
covid_df.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# ...

# %%
# To show the last five Datapoints from the Dataset
covid_df.tail()
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 19491      NaN  International  2020-02-28          705          0
# 19492      NaN  International  2020-02-29          705          0
# 19493      NaN  International  2020-03-01          705          0
# 19494      NaN  International  2020-03-02          705          0
# 19495      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 19491             4           0                      NaN
# 19492             6           2                      NaN
# 19493             6           0                      NaN
# 19494             6           0                      NaN
# 19495             7           1                      NaN
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 19491                    NaN                       NaN  ...            NaN
# ...

# %%
# To show the top 10 data points of the dataset.
covid_df.head(10)
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
# 5      ABW    Aruba  2020-03-27           28          9             0
# 6      ABW    Aruba  2020-03-28           28          0             0
# 7      ABW    Aruba  2020-03-29           28          0             0
# 8      ABW    Aruba  2020-03-30           50         22             0
# 9      ABW    Aruba  2020-04-01           55          5             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# ...

# %%
# To check the columns name and details.
covid_df.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
# To find the Shape of the dataset.
covid_df.shape
# Out:
# (19496, 32)

# %%
# To get the information of the dataset like no. of columns, no. of Entities,Dtype of all elements in columns etc.
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19496 entries, 0 to 19495
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         19432 non-null  object
#  1   location                         19496 non-null  object
#  2   date                             19496 non-null  object
#  3   total_cases                      19496 non-null  int64
#  4   new_cases                        19496 non-null  int64
#  5   total_deaths                     19496 non-null  int64
#  6   new_deaths                       19496 non-null  int64
#  7   total_cases_per_million          19119 non-null  float64
#  8   new_cases_per_million            19119 non-null  float64
#  9   total_deaths_per_million         19119 non-null  float64
#  10  new_deaths_per_million           19119 non-null  float64
#  11  total_tests                      5164 non-null   float64
# ...

# %%
# To check the Total no of elements in the dataset.
covid_df.size
# Out:
# 623872

# %%
# To check the Dimension od the dataset
covid_df.ndim
# Out:
# 2

# %%
# To describe the all function of dataset like Counts ,mean,maximum values,minimum value,standard deviation of all Columns.
covid_df.describe()
# Out:
#         total_cases      new_cases   total_deaths    new_deaths  \
# count  1.949600e+04   19496.000000   19496.000000  19496.000000
# mean   1.752634e+04     540.990152    1162.475739     35.055601
# std    1.808525e+05    4858.071697   12377.578661    334.755956
# min    0.000000e+00   -2461.000000       0.000000      0.000000
# 25%    5.000000e+00       0.000000       0.000000      0.000000
# 50%    8.400000e+01       2.000000       1.000000      0.000000
# 75%    1.135250e+03      43.000000      24.000000      1.000000
# max    5.273572e+06  107909.000000  341722.000000  10520.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             19119.000000           19119.000000
# mean                499.008529              13.312513
# std                1458.509832              63.749619
# min                   0.000000            -265.189000
# 25%                   0.593000               0.000000
# 50%                  26.720000               0.246000
# ...

# %%
# To check the top five null Values in dataset in DataFrame format.
covid_df.isnull().head()
# Out:
#    iso_code  location   date  total_cases  new_cases  total_deaths  \
# 0     False     False  False        False      False         False
# 1     False     False  False        False      False         False
# 2     False     False  False        False      False         False
# 3     False     False  False        False      False         False
# 4     False     False  False        False      False         False
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0       False                    False                  False
# 1       False                    False                  False
# 2       False                    False                  False
# 3       False                    False                  False
# 4       False                    False                  False
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                     False  ...          False          False
# ...

# %%
# To find the null value in each columns. 
covid_df.isnull().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# ...

# %%
# To find the total null value of each columns.
covid_df.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14332
# new_tests                          14904
# total_tests_per_thousand           14332
# new_tests_per_thousand             14904
# new_tests_smoothed                 13866
# new_tests_smoothed_per_thousand    13866
# tests_units                        13267
# stringency_index                    4500
# population                            64
# population_density                   850
# median_age                          1743
# aged_65_older                       1980
# ...

# %%
# To find the data of india from hole dataset in dataframe format.
india_df=covid_df[covid_df['location']=='India']

# %%
# To show the top datapoints of India's data
india_df.head()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8379      IND    India  2019-12-31            0          0             0
# 8380      IND    India  2020-01-01            0          0             0
# 8381      IND    India  2020-01-02            0          0             0
# 8382      IND    India  2020-01-03            0          0             0
# 8383      IND    India  2020-01-04            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8379           0                      0.0                    0.0
# 8380           0                      0.0                    0.0
# 8381           0                      0.0                    0.0
# 8382           0                      0.0                    0.0
# 8383           0                      0.0                    0.0
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
# To check the shape of India's data
india_df.shape
# Out:
# (145, 32)

# %%
# To check From which date the cases started in india with all details.
First_date_covid_case=india_df[india_df['total_cases']>0].iloc[0]
First_date_covid_case['date']
# Out:
# '2020-01-30'

# %%
# To Check on which date first death due to covid in india held.
date_first_death=india_df[india_df['total_deaths']>0].iloc[0]
date_first_death['date']
# Out:
# '2020-03-13'

# %%
# To see the dataset after the covid case death
df_covid_case_death=india_df[india_df['total_deaths']>0]
df_covid_case_death.head()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8451      IND    India  2020-03-13           75          2             1
# 8452      IND    India  2020-03-14           83          8             2
# 8453      IND    India  2020-03-15           90          7             2
# 8454      IND    India  2020-03-16           93          3             2
# 8455      IND    India  2020-03-17          125         32             3
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8451           1                    0.054                  0.001
# 8452           1                    0.060                  0.006
# 8453           0                    0.065                  0.005
# 8454           0                    0.067                  0.002
# 8455           1                    0.091                  0.023
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
#import Visualisation Library .
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# To visualise how the deaths cases increases in the last recent days from the dataset.
plt.figure(figsize=(15,15))
sns.lineplot(y='total_deaths',x=india_df['date'].tail(10),data=india_df)
plt.show()

# %%
# To visualise the total_cases in the last recent days from the dataset.

# %%
plt.figure(figsize=(15,15))
sns.lineplot(x=india_df['date'].tail(10),y='total_cases',data=india_df)
plt.show()

# %%
# To visualise the Total test done for covid in each date
plt.figure(figsize=(10,10))
sns.lineplot(x='date',y='total_tests',data=india_df)
plt.show()

# %%
# To visualise the total test in the last 10 days in india.
plt.figure(figsize=(10,10))
sns.lineplot(x='date',y='total_tests',data=india_df.tail(10))
plt.show()

# %%
# To find the date when total_cases are maximum.
data_top=covid_df.sort_values(by='total_cases',ascending=False).iloc[0:5]
data_top
# Out:
#        iso_code location        date  total_cases  new_cases  total_deaths  \
# 19431  OWID_WRL    World  2020-05-24      5273572      97636        341722
# 19430  OWID_WRL    World  2020-05-23      5175936     106570        338089
# 19429  OWID_WRL    World  2020-05-22      5069366     107909        333399
# 19428  OWID_WRL    World  2020-05-21      4961457      99483        327956
# 19427  OWID_WRL    World  2020-05-20      4861974      95075        323156
#
#        new_deaths  total_cases_per_million  new_cases_per_million  \
# 19431        3633                  676.550                 12.526
# 19430        4690                  664.024                 13.672
# 19429        5443                  650.352                 13.844
# 19428        4800                  636.509                 12.763
# 19427        5228                  623.746                 12.197
#
#        total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
# sorting the data on the bases of last date.
last_date=covid_df[covid_df['date']=='2020-05-24']
last_date.head()
# Out:
#     iso_code     location        date  total_cases  new_cases  total_deaths  \
# 62       ABW        Aruba  2020-05-24          101          0             3
# 198      AFG  Afghanistan  2020-05-24         9998        782           216
# 262      AGO       Angola  2020-05-24           60          0             3
# 321      AIA     Anguilla  2020-05-24            3          0             0
# 398      ALB      Albania  2020-05-24          989          8            31
#
#      new_deaths  total_cases_per_million  new_cases_per_million  \
# 62            0                  945.994                  0.000
# 198          11                  256.831                 20.088
# 262           0                    1.826                  0.000
# 321           0                  199.973                  0.000
# 398           0                  343.665                  2.780
#
#      total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
# To find the top location on last date with maximum cases.
top_location=last_date.sort_values(by='total_cases',ascending=False).iloc[1:6]
top_location
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 18391      USA  United States  2020-05-24      1622670      21236
# 2655       BRA         Brazil  2020-05-24       347398      16508
# 15569      RUS         Russia  2020-05-24       335882       9434
# 9396       ITA          Italy  2020-05-24       229327        669
# 4613       DEU        Germany  2020-05-24       178281        431
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 18391         97087        1080                 4902.287
# 2655          22013         965                 1634.357
# 15569          3388         139                 2301.595
# 9396          32735         119                 3792.922
# 4613           8247          31                 2127.866
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 18391                 64.157                   293.312  ...         15.413
# ...

# %%
# To visualise the top location with total no. of cases.
sns.barplot(x='location',y='total_cases',data=top_location,hue='location')
plt.show()

# %%
# importing train test split model
from sklearn.model_selection import train_test_split

# %%
#converting string date to date-time
import datetime as dt
india_df['date']=pd.to_datetime(india_df['date'])
india_df.head()
# Out:
# <ipython-input-33-20de027c82cb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_df['date']=pd.to_datetime(india_df['date'])
#      iso_code location       date  total_cases  new_cases  total_deaths  \
# 8379      IND    India 2019-12-31            0          0             0
# 8380      IND    India 2020-01-01            0          0             0
# 8381      IND    India 2020-01-02            0          0             0
# 8382      IND    India 2020-01-03            0          0             0
# 8383      IND    India 2020-01-04            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8379           0                      0.0                    0.0
# ...

# %%
#converting date-time to ordinal
india_df['date']=india_df['date'].map(dt.datetime.toordinal)
india_df.head()
# Out:
# <ipython-input-34-621d15370524>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_df['date']=india_df['date'].map(dt.datetime.toordinal)
#      iso_code location    date  total_cases  new_cases  total_deaths  \
# 8379      IND    India  737424            0          0             0
# 8380      IND    India  737425            0          0             0
# 8381      IND    India  737426            0          0             0
# 8382      IND    India  737427            0          0             0
# 8383      IND    India  737428            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8379           0                      0.0                    0.0
# ...

# %%
# Getting Dependent and Independent variable.
x=india_df['date']
y=india_df['total_cases']

# %%
# importing the linear Regression
from sklearn.linear_model import LinearRegression

# %%
# assigning the value to train test variables.
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
# storing linear Regression to a variable
lr=LinearRegression()

# %%
india_df.tail()
# Out:
#      iso_code location    date  total_cases  new_cases  total_deaths  \
# 8519      IND    India  737565       106750       5611          3303
# 8520      IND    India  737566       112359       5609          3435
# 8521      IND    India  737567       118447       6088          3583
# 8522      IND    India  737568       125101       6654          3720
# 8523      IND    India  737569       131868       6767          3867
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8519         140                   77.355                  4.066
# 8520         132                   81.419                  4.064
# 8521         148                   85.831                  4.412
# 8522         137                   90.653                  4.822
# 8523         147                   95.556                  4.904
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 8519                     2.393  ...          5.989          3.414
# ...

# %%
# Training the data
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
# Testing the data
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
# importing the mean squared error method
from sklearn.metrics import mean_squared_error

# %%
# find the mean square error
mean_squared_error(x_test,y_pred)
# Out:
# 523676336990.37164
